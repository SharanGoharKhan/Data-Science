# %%
# %pylab inline
import scipy.stats
from collections import defaultdict
import re
import tools as t
plt.style.use('ggplot')
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)
# %load_ext autoreload 
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# You can change tdir variable if your directory is different that this

tdir='./data/imdb1/' # training dir...
#load data, get list of files for each class...
posfiles=t.get_files(tdir+'/pos','*',withpath=True)
negfiles=t.get_files(tdir+'/neg','*',withpath=True)

# %%
#generate training and testing data...
plabels=['pos']*len(posfiles)
nlabels=['neg']*len(posfiles)
Y=np.concatenate((plabels,nlabels)) # concatenate the +ve and -ve labels
tX=np.concatenate((posfiles,negfiles)).reshape((len(posfiles)+len(negfiles),1))
print "Training data Dimensions =", tX.shape," Training labels dimensions=", Y.shape
# Out:
# Training data Dimensions = (2000, 1)  Training labels dimensions= (2000,)

# %%
def parse_string(string):    
    return string.split()

def parse_file(filename): # Parse a given file
    with open(filename,'r') as rfile:
        rstring=rfile.read()    
    return rstring

def files_to_strings(X):
    rX=np.zeros((X.shape[0],1),dtype=object)
    for ei in range(X.shape[0]):
        rX[ei,0]=parse_file(X[ei][0])
        
    return rX

# %%
X=files_to_strings(tX).flatten() # reads files and convert each file into set of strings and return an numpy array

# %%
print X.shape
print Y.shape
# Out:
# (2000,)
# (2000,)

# %% [markdown]
# ### Sklearn Majic begins

# %%
from sklearn.cross_validation import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# #### Splitting into test / train
# *Hint : Use Train Test Split*

# %%
# your code goes here

# %% [markdown]
# #### Create vocablary and transform data
# *Hint : Use Count vectorizer*
# - .fit()
# - .transform()

# %%
# you code goes here
count_vect_train_transformer = CountVectorizer()
count_vect_train = count_vect_train_transformer.fit_transform(train_data)

# %% [markdown]
# #### Let's take a look at the vocablary
# *Hint : Use attribute vocablary_*

# %%
count_vect_train_transformer.vocabulary_
# Out:
# {u'raining': 21055,
#  u'hordes': 12621,
#  u'unwinable': 28090,
#  u'sonja': 24563,
#  u'unsworth': 28054,
#  u'neckties': 17689,
#  u'woods': 29356,
#  u'testosterone': 26487,
#  u'bazooms': 2500,
#  u'hanging': 11880,
#  u'woody': 29360,
#  u'comically': 5255,
#  u'localized': 15556,
#  u'disobeying': 7562,
#  u'hennings': 12241,
#  u'topples': 26946,
#  u'scold': 23080,
#  u'quadruple': 20888,
#  u'gab': 10685,
#  u'originality': 18519,
#  u'ryanson': 22661,
#  u'tingle': 26796,
#  u'mutinies': 17493,
#  u'demoted': 6969,
#  u'rickman': 22207,
#  u'immature': 13075,
#  u'meadows': 16467,
#  u'sinking': 24001,
#  u'callin': 3958,
#  u'stallone': 25026,
#  u'wracked': 29438,
#  u'oceans': 18248,
#  u'stabber': 24980,
#  u'stipulate': 25249,
#  u'pharoah': 19476,
#  u'tantalizing': 26203,
#  u'rawhide': 21213,
#  u'needfully': 17695,
#  u'stabbed': 24979,
#  u'bringing': 3556,
#  u'picaresque': 19548,
#  u'four': 10400,
#  u'disturb': 7673,
#  u'recollections': 21367,
#  u'liaisons': 15296,
#  u'wooden': 29353,
#  u'voyeur': 28667,
#  u'wednesday': 28935,
#  u'brutish': 3650,
#  u'circuitry': 4804,
#  u'crotch': 6263,
#  u'elgar': 8483,
#  u'stereotypical': 25186,
#  u'busybody': 3856,
#  u'commented': 5281,
#  u'sturm': 25527,
#  u'sooty': 24580,
#  u'insular': 13672,
#  u'bilk': 2852,
#  u'francesco': 10435,
#  u'frederick': 10481,
#  u'eclipsed': 8313,
#  u'feasibility': 9684,
#  u'miniatures': 16865,
#  u'cary': 4198,
#  u'gorman': 11318,
#  u'francesca': 10434,
#  u'melvin': 16579,
#  u'loathing': 15544,
#  u'childers': 4629,
#  u'cobbling': 5060,
#  u'inanimate': 13240,
#  u'errors': 8966,
#  u'relieving': 21669,
#  u'roddy': 22403,
#  u'thunder': 26701,
#  u'cooking': 5828,
#  u'moniters': 17119,
#  u'idziak': 12982,
#  u'trainer': 27088,
#  u'straights': 25338,
#  u'aggression': 952,
#  u'videodrome': 28453,
#  u'outfielders': 18604,
#  u'resilient': 21927,
#  u'goldfinger': 11242,
#  u'succumb': 25634,
#  u'shocks': 23725,
#  u'housewarming': 12703,
#  u'chins': 4649,
#  u'jubilantly': 14345,
#  u'47': 248,
#  u'china': 4645,
#  u'punks': 20802,
#  u'cult': 6355,
#  u'shandling': 23574,
#  u'wiseguy': 29265,
#  u'natured': 17628,
#  u'darkness': 6584,
#  u'kids': 14625,
#  u'uplifting': 28115,
#  u'unwillingness': 28089,
#  u'oxford': 18814,
#  u'elaborate': 8431,
#  u'eligible': 8493,
#  u'controversy': 5779,
#  u'kario': 14472,
#  u'neurologist': 17776,
#  u'rulebook': 22598,
#  u'spotty': 24883,
#  u'delicacy': 6887,
#  u'climber': 4954,
#  u'criticism': 6222,
#  u'appropriately': 1593,
#  u'_would_': 462,
#  u'projection': 20522,
#  u'flotsam': 10162,
#  u'cranium': 6101,
#  u'wizardry': 29310,
#  u'unsinkable': 28028,
#  u'stern': 25191,
#  u'namuth': 17560,
#  u'obligation': 18169,
#  u'kethcum': 14571,
#  u'opponents': 18428,
#  u'dna': 7732,
#  u'superficially': 25759,
#  u'catchy': 4255,
#  u'insecurity': 13593,
#  u'cannibal': 4035,
#  u'prospector': 20618,
#  u'cents': 4370,
#  u'symphony': 26048,
#  u'music': 17464,
#  u'therefore': 26555,
#  u'onassis': 18361,
#  u'strike': 25417,
#  u'caned': 4028,
#  u'care': 4108,
#  u'magyuver': 15948,
#  u'drawbacks': 7985,
#  u'paperwork': 18961,
#  u'forementioned': 10307,
#  u'43': 244,
#  u'yahoo': 29533,
#  u'faceted': 9464,
#  u'meteorologist': 16698,
#  u'sputter': 24934,
#  u'boorman': 3248,
#  u'lord': 15664,
#  u'tarsem': 26232,
#  u'foregrounds': 10300,
#  u'primeval': 20369,
#  u'rancor': 21103,
#  u'voicework': 28617,
#  u'circumstances': 4811,
#  u'reingold': 21594,
#  u'tastefully': 26242,
#  u'morally': 17188,
#  u'locked': 15567,
#  u'daqughter': 6563,
#  u'magritte': 15944,
#  u'pursue': 20845,
#  u'plunged': 19836,
#  u'locker': 15568,
#  u'soundbite': 24619,
#  u'gershon': 10975,
#  u'exhale': 9237,
#  u'rework': 22149,
#  u'plunges': 19837,
#  u'example': 9152,
#  u'expressively': 9362,
#  u'prefacing': 20217,
#  u'deputy': 7050,
#  u'wang': 28771,
#  u'wane': 28770,
#  u'unjust': 27912,
#  u'table': 26082,
#  u'vehemently': 28321,
#  u'pooper': 19952,
#  u'hormone': 12625,
#  u'caution': 4293,
#  u'want': 28777,
#  u'counseling': 5978,
#  u'pinto': 19642,
#  u'phaedra': 19467,
#  u'absolute': 543,
#  u'vicent': 28427,
#  u'beyer': 2804,
#  u'travel': 27180,
#  u'copious': 5855,
#  u'kyzynski': 14855,
#  u'groaner': 11553,
#  u'clubbing': 5016,
#  u'dangerfield': 6537,
#  u'chisolm': 4659,
#  u'dared': 6568,
#  u'prostitues': 20625,
#  u'shrug': 23834,
#  u'dignified': 7327,
#  u'fanaticism': 9558,
#  u'thivisol': 26609,
#  u'sonorra': 24569,
#  u'stravinsky': 25376,
#  u'ackland': 660,
#  u'slaparound': 24149,
#  u'despondent': 7123,
#  u'dinosaurs': 7377,
#  u'wrong': 29484,
#  u'cerebrally': 4380,
#  u'sentencing': 23393,
#  u'italy': 14013,
#  u'hurricaine': 12849,
#  u'opted': 18448,
#  u'entrusted': 8858,
#  u'glenne': 11130,
#  u'sets': 23465,
#  u'recombination': 21368,
#  u'seduce': 23269,
#  u'nympho': 18142,
#  u'subplots': 25576,
#  u'sickening': 23863,
#  u'tulip': 27395,
#  u'18th': 85,
#  u'perpetrator': 19369,
#  u'crackin': 6079,
#  u'nonsensical': 17972,
#  u'disengaging': 7508,
#  u'bilking': 2853,
#  u'snugly': 24448,
#  u'kuei': 14830,
#  u'welcomed': 28971,
#  u'stoicism': 25270,
#  u'whizzing': 29100,
#  u'partnered': 19057,
#  u'sidekicks': 23873,
#  u'butcher': 3861,
#  u'rewarded': 22144,
#  u'owens': 18805,
#  u'wrought': 29493,
#  u'zak': 29671,
#  u'hypnotist': 12898,
#  u'wickedly': 29135,
#  u'reprises': 21851,
#  u'fit': 9987,
#  u'benign': 2709,
#  u'lifeline': 15355,
#  u'screaming': 23133,
#  u'fix': 9998,
#  u'_i_know_what_you_did_last_summer_': 396,
#  u'survivors': 25879,
#  u'reprised': 21850,
#  u'fig': 9846,
#  u'insubstantial': 13670,
#  u'isaak': 13975,
#  u'wales': 28729,
#  u'fin': 9899,
#  u'easier': 8278,
#  u'zucker': 29735,
#  u'songwriter': 24560,
#  u'pitfall': 19673,
#  u'slate': 24161,
#  u'scientology': 23073,
#  u'basics': 2435,
#  u'guiler': 11659,
#  u'effects': 8376,
#  u'interrupt': 13784,
#  u'uttering': 28198,
#  u'sixteen': 24040,
#  u'eisenhower': 8422,
#  u'saddened': 22699,
#  u'scholar': 23017,
#  u'holnist': 12513,
#  u'weekened': 28942,
#  u'whacking': 29015,
#  u'renditions': 21755,
#  u'barton': 2418,
#  u'foregin': 10296,
#  u'neutron': 17782,
#  u'arrow': 1734,
#  u'ingrid': 13502,
#  u'volcano': 28627,
#  u'deadeningly': 6653,
#  u'gumshoe': 11682,
#  u'burial': 3790,
#  u'telescope': 26362,
#  u'archetypes': 1634,
#  u'palmieri': 18904,
#  u'allah': 1111,
#  u'allan': 1112,
#  u'parasites': 18999,
#  u'delgado': 6880,
#  u'dga': 7233,
#  u'tragicomic': 27080,
#  u'kirkeby': 14690,
#  u'message': 16671,
#  u'ru': 22565,
#  u'rv': 22658,
#  u'drove': 8079,
#  u'antiheroes': 1473,
#  u'oprah': 18446,
#  u'108': 16,
#  u'smirk': 24324,
#  u'indiscretion': 13374,
#  u'freeze': 10495,
#  u'nordoff': 17984,
#  u'mason': 16259,
#  u'rd': 21222,
#  u're': 21223,
#  u'encourage': 8679,
#  u'adapt': 721,
#  u'donahue': 7815,
#  u'ro': 22332,
#  u'outburst': 18590,
#  u'speed2': 24740,
#  u'murilo': 17444,
#  u'foundation': 10391,
#  u'stamping': 25034,
#  u'abbots': 482,
#  u'dracula': 7951,
#  u'succession': 25628,
#  u'threatened': 26647,
#  u'rocker': 22389,
#  u'pumpkins': 20778,
#  u'overacting': 18670,
#  u'faculties': 9485,
#  u'elsewhere': 8533,
#  u'crowned': 6277,
#  u'lesbo': 15240,
#  u'universally': 27908,
#  u'silent': 23925,
#  u'husbands': 12859,
#  u'enormous': 8779,
#  u'exposing': 9349,
#  u'r2': 20980,
#  u'sickeningly': 23864,
#  u'mcqueen': 16462,
#  u'shipped': 23701,
#  u'disturbed': 7676,
#  u'speedy': 24745,
#  u'competed': 5348,
#  u'tempting': 26392,
#  u'1970s': 134,
#  u'reserving': 21910,
#  u'loudness': 15694,
#  u'symbolize': 26034,
#  u'caught': 4283,
#  u'speeds': 24744,
#  u'juergen': 14364,
#  u'tantor': 26206,
#  u'steroids': 25194,
#  u'dailies': 6474,
#  u'disfigured': 7509,
#  u'slayings': 24180,
#  u'visited': 28569,
#  u'procreate': 20449,
#  u'elena': 8471,
#  u'megabytes': 16543,
#  u'clarity': 4863,
#  u'olds': 18332,
#  u'basketball': 2442,
#  u'service': 23449,
#  u'forrester': 10365,
#  u'corsucant': 5933,
#  u'reuben': 22067,
#  u'needed': 17694,
#  u'master': 16276,
#  u'livelihoods': 15512,
#  u'brashness': 3428,
#  u'weendigo': 28946,
#  u'caitlyn': 3936,
#  u'imcomprehinsable': 13062,
#  u'rewards': 22146,
#  u'enthrall': 8823,
#  u'bacon': 2209,
#  u'asner': 1806,
#  u'rectified': 21414,
#  u'task': 26235,
#  u'mutilated': 17490,
#  u'pulse': 20769,
#  u'_the': 444,
#  u'crawl': 6123,
#  u'golden': 11238,
#  u'positively': 20038,
#  u'tires': 26818,
#  u'ahmed': 983,
#  u'heirs': 12192,
#  u'showed': 23799,
#  u'bannister': 2333,
#  u'handcuffs': 11849,
#  u'tree': 27213,
#  u'rusty': 22653,
#  u'idly': 12975,
#  u'shower': 23800,
#  u'idle': 12974,
#  u'exclaimed': 9198,
#  u'sheen': 23629,
#  u'aftereffects': 924,
#  u'panaro': 18921,
#  u'feeling': 9715,
#  u'forfeited': 10320,
#  u'valiant': 28231,
#  u'willingness': 29184,
#  u'scalper': 22927,
#  u'longs': 15623,
#  u'sustaining': 25902,
#  u'spectrum': 24730,
#  u'craven': 6119,
#  u'antagonistic': 1446,
#  u'longo': 15622,
#  u'urinate': 28160,
#  u'dozen': 7944,
#  u'pompous': 19932,
#  u'affairs': 879,
#  u'allayah': 1113,
#  u'wholesome': 29108,
#  u'courier': 6022,
#  u'partridge': 19061,
#  u'portillo': 20001,
#  u'bleachers': 2992,
#  u'rudolph': 22582,
#  u'gripe': 11538,
#  u'haste': 12008,
#  u'racers': 20993,
#  u'recommended': 21374,
#  u'instructs': 13665,
#  u'amusing': 1299,
#  u'nuez': 18091,
#  u'sores': 24597,
#  u'grips': 11542,
#  u'orphaned': 18534,
#  u'reelection': 21469,
#  u'aggravate': 949,
#  u'committing': 5302,
#  u'lion': 15463,
#  u'thrilled': 26660,
#  u'limitless': 15419,
#  u'diminishing': 7356,
#  u'cinematic': 4784,
#  u'resonates': 21942,
#  u'disjointed': 7538,
#  u'dosmo': 7875,
#  u'mouth': 17315,
#  u'addict': 733,
#  u'organization': 18496,
#  u'thriller': 26661,
#  u'bradford': 3385,
#  u'dummy': 8161,
#  u'singer': 23984,
#  u'snooping': 24426,
#  u'cams': 4005,
#  u'camp': 3993,
#  u'rotary': 22513,
#  u'passes': 19077,
#  u'arli': 1683,
#  u'zant': 29676,
#  u'tech': 26309,
#  u'fugitives': 10607,
#  u'arlo': 1686,
#  u'detriment': 7178,
#  u'mating': 16332,
#  u'scream': 23130,
#  u'came': 3977,
#  u'fonda': 10243,
#  u'saying': 22916,
#  u'inmates': 13552,
#  u'insects': 13590,
#  u'meetings': 16539,
#  u'teresa': 26431,
#  u'rosselini': 22505,
#  u'padded': 18845,
#  u'hillbillies': 12368,
#  u'jungle2jungle': 14399,
#  u'participate': 19041,
#  u'lethal': 15258,
#  u'tempted': 26391,
#  u'cheaply': 4541,
#  u'seediness': 23281,
#  u'eliminated': 8496,
#  u'hounded': 12688,
#  u'lessons': 15251,
#  u'orleans': 18528,
#  u'flowers': 10173,
#  u'clicked': 4938,
#  u'itinerant': 14019,
#  u'headline': 12090,
#  u'katzenberg': 14502,
#  u'than': 26506,
#  u'rico': 22210,
#  u'bliss': 3021,
#  u'rick': 22203,
#  u'rich': 22190,
#  u'rice': 22189,
#  u'rica': 22185,
#  u'plate': 19733,
#  u'ludicrous': 15769,
#  u'joely': 14256,
#  u'hoggett': 12477,
#  u'plato': 19738,
#  u'denounce': 6991,
#  u'psychiatric': 20706,
#  u'foremost': 10308,
#  u'platt': 19742,
#  u'clumsiness': 5024,
#  u'altogether': 1192,
#  u'relish': 21677,
#  u'societies': 24470,
#  u'profoundly': 20497,
#  u'sittings': 24033,
#  u'autistic': 2061,
#  u'nicely': 17839,
#  u'boarder': 3128,
#  u'patch': 19102,
#  u'openly': 18405,
#  u'stunningly': 25509,
#  u'earthling': 8270,
#  u'adherence': 761,
#  u'boarded': 3127,
#  u'saul': 22880,
#  u'heirloom': 12191,
#  u'sensitivity': 23383,
#  u'pinon': 19638,
#  u'recruit': 21407,
#  u'pads': 18850,
#  u'radius': 21024,
#  u'cloning': 4984,
#  u'weird': 28958,
#  u'resigned': 21923,
#  u'pricking': 20349,
#  u'embarks': 8552,
#  u'playfulness': 19759,
#  u'pressured': 20296,
#  u'lots': 15685,
#  u'irs': 13966,
#  u'rings': 22274,
#  u'droves': 8080,
#  u'bandaras': 2302,
#  u'avery': 2098,
#  u'humankind': 12780,
#  u'skimps': 24095,
#  u'ira': 13923,
#  u'ire': 13928,
#  u'skimpy': 24096,
#  u'wage': 28696,
#  u'interrupting': 13786,
#  u'extend': 9371,
#  u'nature': 17627,
#  u'lapping': 14986,
#  u'extent': 9378,
#  u'defiance': 6815,
#  u'sancho': 22804,
#  u'reacquaints': 21230,
#  u'tyranny': 27515,
#  u'planner': 19721,
#  u'veer': 28312,
#  u'disdain': 7499,
#  u'voyeuristic': 28668,
#  u'incense': 13256,
#  u'planned': 19720,
#  u'lookin': 15635,
#  u'marrying': 16211,
#  u'carwash': 4197,
#  u'argue': 1657,
#  u'eradicate': 8928,
#  u'zigged': 29705,
#  u'obscenity': 18186,
#  u'elfman': 8482,
#  u'chains': 4406,
#  u'way': 28880,
#  u'gopher': 11302,
#  u'munches': 17423,
#  u'trickiest': 27260,
#  u'smithereens': 24331,
#  u'hers': 12291,
#  u'charnel': 4503,
#  u'gleaming': 11118,
#  u'affiliated': 892,
#  u'pregnancy': 20228,
#  u'humming': 12800,
#  u'passionless': 19083,
#  u'yale': 29537,
#  u'slobby': 24238,
#  u'milquetoast': 16824,
#  u'union': 27894,
#  u'shriek': 23823,
#  u'fro': 10560,
#  u'bothers': 3310,
#  u'much': 17362,
#  u'wyman': 29507,
#  u'stadium': 24995,
#  u'progenitor': 20503,
#  u'privilege': 20404,
#  u'deliberately': 6884,
#  u'fry': 10591,
#  u'adroitly': 825,
#  u'tswsm': 27380,
#  u'obese': 18152,
#  u'electrocution': 8456,
#  u'retrospect': 22060,
#  u'spit': 24814,
#  u'arkin': 1681,
#  u'worker': 29384,
#  u'allotting': 1139,
#  u'trunchbull': 27354,
#  u'boardroom': 3130,
#  u'dave': 6620,
#  u'strewn': 25410,
#  u'doubts': 7896,
#  u'worked': 29383,
#  u'haters': 12021,
#  u'spin': 24790,
#  u'costanza': 5950,
#  u'goop': 11300,
#  u'gritty': 11549,
#  u'solvable': 24530,
#  u'mesmerising': 16668,
#  u'shoring': 23756,
#  u'employ': 8637,
#  u'nfeatured': 17827,
#  u'misconstrued': 16930,
#  u'viii': 28487,
#  u'sourabaya': 24632,
#  u'bin': 2871,
#  u'morante': 17193,
#  u'cornish': 5897,
#  u'ditching': 7683,
#  u'distorted': 7652,
#  u'kohn': 14778,
#  u'lackies': 14879,
#  u'taunts': 26262,
#  u'overpowers': 18743,
#  u'eighteen': 8413,
#  u'upscale': 28132,
#  u'anticipating': 1465,
#  u'keegan': 14519,
#  u'hyperdrive': 12886,
#  u'violin': 28533,
#  u'oxymoron': 18816,
#  u'breakfast': 3463,
#  u'hone': 12554,
#  u'memorial': 16590,
#  u'recover': 21396,
#  u'severity': 23490,
#  u'portobello': 20009,
#  u'mummified': 17419,
#  u'orgazmo': 18507,
#  u'spews': 24762,
#  u'split': 24835,
#  u'zoolander': 29727,
#  u'thinly': 26594,
#  u'elliott': 8519,
#  u'principals': 20377,
#  u'cavanaugh': 4298,
#  u'european': 9060,
#  u'voyager': 28665,
#  u'voyages': 28666,
#  u'thereof': 26557,
#  u'boiled': 3170,
#  u'effortlessly': 8385,
#  u'transfixed': 27116,
#  u'inadvertently': 13236,
#  u'vivien': 28598,
#  u'torpedoes': 26970,
#  u'marched': 16138,
#  u'boiler': 3171,
#  u'vigo': 28484,
#  u'mckellen': 16450,
#  u'lucas': 15752,
#  u'noblewoman': 17931,
#  u'detracted': 7173,
#  u'academic': 575,
#  u'stillness': 25229,
#  u'academia': 574,
#  u'goofing': 11292,
#  u'simulated': 23967,
#  u'corresponded': 5920,
#  u'waitering': 28717,
#  u'corporate': 5904,
#  u'guccione': 11634,
#  u'gigolo': 11038,
#  u'letterman': 15268,
#  u'absurdities': 557,
#  u'murtaugh': 17451,
#  u'connell': 5581,
#  u'sleepy': 24197,
#  u'terrorist': 26468,
#  u'homogeneity': 12545,
#  u'honsou': 12576,
#  u'lasse': 15013,
#  u'subdued': 25551,
#  u'credited': 6156,
#  u'portrayed': 20015,
#  u'amusingly': 1300,
#  u'lasso': 15018,
#  u'hai': 11768,
#  u'spectacles': 24723,
#  u'hal': 11791,
#  u'ham': 11820,
#  u'han': 11846,
#  u'had': 11754,
#  u'advancement': 837,
#  u'coverup': 6052,
#  u'hay': 12056,
#  u'mcnamara': 16457,
#  u'beloved': 2685,
#  u'duffel': 8135,
#  u'traeger': 27070,
#  u'har': 11913,
#  u'has': 11999,
#  u'hat': 12010,
#  u'buffoonish': 3693,
#  u'riboud': 22183,
#  u'quirk': 20952,
#  u'elders': 8440,
#  u'survival': 25873,
#  u'online': 18374,
#  u'cliche': 4934,
#  u'unequivocally': 27788,
#  u'otherworldly': 18569,
#  u'indicative': 13359,
#  u'shadow': 23530,
#  u'replace': 21813,
#  u'ballhaus': 2272,
#  u'sleuthing': 24202,
#  u'brought': 3617,
#  u'keeve': 14533,
#  u'alice': 1093,
#  u'noteables': 18032,
#  u'cogs': 5102,
#  u'festivities': 9783,
#  u'spontenaity': 24856,
#  u'grotesquely': 11578,
#  u'misdemeanors': 16933,
#  u'unabashedly': 27562,
#  u'attorney': 1985,
#  u'sordid': 24594,
#  u'creek': 6162,
#  u'crowd': 6272,
#  u'crowe': 6275,
#  u'dispatch': 7575,
#  u'creed': 6161,
#  u'crown': 6276,
#  u'topping': 26943,
#  u'crows': 6278,
#  u'arija': 1668,
#  u'lions': 15467,
#  u'billboard': 2856,
#  u'harassment': 11918,
#  u'creep': 6163,
#  u'enemies': 8715,
#  u'anne': 1412,
#  u'cocaine': 5065,
#  u'bottom': 3316,
#  u'pileggi': 19599,
#  u'inhuman': 13520,
#  u'plucked': 19819,
#  u'contributing': 5765,
#  u'kissner': 14701,
#  u'exposition': 9350,
#  u'periphery': 19348,
#  u'surging': 25838,
#  u'monogamy': 17127,
#  u'seagrave': 23206,
#  u'whelming': 29034,
#  u'palatable': 18885,
#  u'shaker': 23551,
#  u'shakes': 23552,
#  u'rooker': 22466,
#  u'memorably': 16589,
#  u'fish': 9975,
#  u'rep': 21782,
#  u'barcode': 2359,
#  u'unfrozen': 27836,
#  u'substituted': 25594,
#  u'styling': 25533,
#  u'starring': 25078,
#  u'loyalist': 15744,
#  u'losing': 15680,
#  u'memorable': 16588,
#  u'bamboo': 2291,
#  u'shaken': 23550,
#  u'stoker': 25272,
#  u'restlessness': 21988,
#  u'benches': 2695,
#  u'filmcritic': 9878,
#  u'bicentennial': 2817,
#  u'oneness': 18370,
#  u'blathers': 2983,
#  u'kilgore': 14636,
#  u'dahlings': 6473,
#  u'match': 16302,
#  u'hulking': 12768,
#  u'soc': 24463,
#  u'sod': 24481,
#  u'facility': 9470,
#  u'kinky': 14678,
#  u'maxwell': 16379,
#  u'marshall': 16217,
#  u'honeymoon': 12560,
#  u'mba': 16395,
#  u'liebes': 15337,
#  u'son': 24555,
#  u'thankful': 26510,
#  u'beings': 2639,
#  u'daffy': 6466,
#  u'magazines': 15919,
#  u'marshals': 16219,
#  u'sow': 24646,
#  u'wrap': 29440,
#  u'sox': 24647,
#  u'shoots': 23746,
#  u'authorizes': 2057,
#  u'despised': 7119,
#  u'appealingly': 1541,
#  u'coordinators': 5846,
#  u'spicebus': 24769,
#  u'altitude': 1189,
#  u'constantly': 5653,
#  u'nova': 18061,
#  u'raped': 21133,
#  u'humorous': 12807,
#  u'grasping': 11424,
#  u'despises': 7120,
#  u'authorized': 2056,
#  u'greatness': 11463,
#  u'rapes': 21134,
#  u'bloomington': 3068,
#  u'trappings': 27166,
#  u'launching': 15058,
#  u'grooms': 11562,
#  u'safeties': 22720,
#  u'abundantly': 562,
#  u'manmade': 16090,
#  u'malicious': 16011,
#  u'palmetto': 18903,
#  u'otter': 18571,
#  u'underdeveloped': 27684,
#  u'duel': 8129,
#  u'humbled': 12787,
#  u'masquerading': 16261,
#  u'extremity': 9417,
#  u'inside': 13602,
#  u'flirtatiously': 10127,
#  u'smashes': 24306,
#  u'1600s': 59,
#  u'nicest': 17842,
#  u'smashed': 24305,
#  u'duet': 8133,
#  u'dues': 8132,
#  u'30m': 218,
#  u'passenger': 19075,
#  u'hurley': 12844,
#  u'disgrace': 7510,
#  u'spheeris': 24763,
#  u'barrymore': 2409,
#  u'steady': 25131,
#  u'mirror': 16909,
#  u'unnerve': 27952,
#  u'yankovich': 29546,
#  u'textbook': 26494,
#  u'playboy': 19752,
#  u'decapitation': 6707,
#  u'females': 9740,
#  u'triangles': 27247,
#  u'madwoman': 15911,
#  u'spacemusic': 24656,
#  u'eventual': 9090,
#  u'glacier': 11085,
#  u'dowling': 7913,
#  u'detracts': 7177,
#  u'cloaks': 4974,
#  u'pasadena': 19067,
#  u'role': 22421,
#  u'minefield': 16856,
#  u'rolf': 22423,
#  u'entomologist': 8846,
#  u'wreaked': 29447,
#  u'vegetative': 28319,
#  u'wordlessly': 29372,
#  u'roll': 22424,
#  u'reggae': 21532,
#  u'holt': 12519,
#  u'intend': 13703,
#  u'models': 17046,
#  u'geezer': 10875,
#  u'transported': 27152,
#  u'palme': 18901,
#  u'comely': 5241,
#  u'intent': 13713,
#  u'smelling': 24313,
#  u'variable': 28278,
#  u'cleaver': 4919,
#  u'burbon': 3772,
#  u'hawkes': 12050,
#  u'explosions': 9339,
#  u'loren': 15668,
#  u'99': 327,
#  u'shootout': 23744,
#  u'fastened': 9622,
#  u'unentertaining': 27784,
#  u'rockers': 22390,
#  u'glass': 11112,
#  u'typically': 27508,
#  u'contacts': 5689,
#  u'filing': 9869,
#  u'overturned': 18783,
#  u'someplace': 24542,
#  u'subvert': 25616,
#  u'expletitive': 9315,
#  u'gown': 11347,
#  u'posed': 20022,
#  u'childs': 4634,
#  u'cincinnati': 4779,
#  u'chain': 4404,
#  u'whoever': 29105,
#  u'goddammit': 11206,
#  u'activated': 689,
#  u'naoto': 17570,
#  u'theaters': 26519,
#  u'bandits': 2308,
#  u'dominguez': 7807,
#  u'chair': 4408,
#  u'muppet': 17433,
#  u'midst': 16760,
#  u'macht': 15875,
#  u'ballet': 2270,
#  u'malintentioned': 16015,
#  u'grapples': 11421,
#  u'rambling': 21078,
#  u'terrifying': 26462,
#  u'caldwell': 3945,
#  u'afi': 906,
#  u'freelance': 10489,
#  u'obsessively': 18208,
#  u'lara': 14993,
#  u'crates': 6118,
#  u'crater': 6117,
#  u'silencers': 23924,
#  u'bribed': 3519,
#  u'phnah': 19509,
#  u'macho': 15874,
#  u'oversight': 18766,
#  u'bogus': 3166,
#  u'tenacious': 26395,
#  u'paychecks': 19171,
#  u'icing': 12929,
#  u'jerk': 14170,
#  u'prances': 20149,
#  u'spate': 24694,
#  u'choice': 4670,
#  u'metamorphoses': 16685,
#  u'embark': 8550,
#  u'gloomy': 11158,
#  u'ghostbusters': 11002,
#  u'stays': 25126,
#  u'spats': 24696,
#  u'fretting': 10520,
#  u'exact': 9135,
#  u'minute': 16891,
#  u'cooks': 5829,
#  u'bertolini': 2755,
#  u'amoral': 1277,
#  u'valley': 28237,
#  u'masturbates': 16293,
#  u'minnie': 16883,
#  u'skewed': 24081,
#  u'leave': 15137,
#  u'tap': 26210,
#  u'coincidences': 5117,
#  u'aviators': 2100,
#  u'burned': 3798,
#  u'shelley': 23645,
#  u'skewer': 24082,
#  u'speculation': 24733,
#  u'caddies': 3913,
#  u'cinemtography': 4792,
#  u'wannabes': 28776,
#  u'spiritual': 24810,
#  u'accomplishment': 614,
#  u'xenophobe': 29515,
#  u'evaporating': 9078,
#  u'sigh': 23892,
#  u'sign': 23901,
#  u'heavyweight': 12149,
#  u'plotholes': 19809,
#  u'chopping': 4689,
#  u'shirts': 23711,
#  u'anaconda': 1307,
#  u'ogled': 18310,
#  u'inhibits': 13519,
#  u'massironi': 16272,
#  u'khe': 14594,
#  u'jeopardy': 14166,
#  u'celebrated': 4327,
#  u'melt': 16574,
#  u'300': 215,
#  u'maximilian': 16373,
#  u'lazily': 15097,
#  u'ground': 11582,
#  u'boost': 3250,
#  ...}

# %% [markdown]
# #### Neive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

# %% [markdown]
# #### Lets train and test our classifier
# *Hint : Make an object and :*
# - .fit()
# - .transform()

# %%
# you code goes here
clf = MultinomialNB()
clf.fit(count_vect_train,train_label)
b=count_vect_train_transformer.transform(test_data)
p=clf.predict(b)

# %%
from sklearn import metrics

# %% [markdown]
# *Hint : Use metrics.accuracy_score*

# %%
# you code goes here
print metrics.accuracy_score(test_label,p)
# Out:
# 0.791
